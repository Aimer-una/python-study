# %%
import pandas as pd
# 构造DataFrame --- 创建数据集(学生成绩信息)
df = pd.DataFrame([
    {"姓名":"小王","性别":"男","年龄":"14","语文":90,"英语":80,"数学":70},
    {"姓名":"小李","性别":"男","年龄":"14","语文":80,"英语":90,"数学":80},
    {"姓名":"小明","性别":"男","年龄":"14","语文":70,"英语":70,"数学":70},
    {"姓名":"小吴","性别":"男","年龄":"14","语文":60,"英语":60,"数学":60},
    {"姓名":"小雅","性别":"男","年龄":"14","语文":50,"英语":50,"数学":50},
    {"姓名":"小婷","性别":"男","年龄":"14","语文":40,"英语":40,"数学":40},
    {"姓名":"小润","性别":"男","年龄":"14","语文":30,"英语":30,"数学":30},
])
# 统计计算
print(f"语文最高分:{df['语文'].max()},最低分:{df['语文'].min()},平均分:{df['语文'].mean():.2f}")
print(f"英语最高分:{df['英语'].max()},最低分:{df['英语'].min()},平均分:{df['英语'].mean():.2f}")
print(f"数学最高分:{df['数学'].max()},最低分:{df['数学'].min()},平均分:{df['数学'].mean():.2f}")
# Out:
# 语文最高分:90,最低分:30,平均分:60.00
# 英语最高分:90,最低分:30,平均分:60.00
# 数学最高分:80,最低分:30,平均分:57.14
